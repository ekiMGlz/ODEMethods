# %%
import odesolver
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
f = lambda t, y : 2*(t+1)*y
soln = lambda t : np.exp(t*(t+2))

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'Explicit Euler')

plt.plot(T,W[0],T,soln(T))
plt.title("Explicit Euler")
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-4,10)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'Implicit Euler')

plt.plot(T,W[0],T,soln(T))
plt.title("Implicit Euler")
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-4,10)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'Explicit Trapezoid')

plt.plot(T,W[0],T,soln(T))
plt.title("Explicit Trapezoid")
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-6, 1)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'Implicit Trapezoid')

plt.plot(T,W[0],T,soln(T))
plt.title("Implicit Trapezoid")
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-6, 1)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'Explicit Midpoint')

plt.plot(T,W[0],T,soln(T))
plt.title("Explicit Midpoint")
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-6,1)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'RK4')

plt.plot(T,W[0],T,soln(T))
plt.title('RK4')
plt.show()

# %%
globalError = abs(soln(T) - W[0])
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-10,1)
plt.show()

# %%
T,W = odesolver.solve(f, 1, (0,1), 50, method = 'RK23')

plt.plot(T,W,T,soln(T))
plt.title("RK23")
plt.show()

# %%
globalError = abs(soln(T) - W)
plt.title('Error Global Absoluto - Escala Logaritmica')
plt.scatter(range(len(globalError)), globalError, marker = 'x')
plt.yscale('log')
plt.ylim(1e-5,1)
plt.show()
